# %%
import pandas as pd

# %%
eng = pd.read_csv('players_20.csv')  #displays all players dataset
eng
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age        dob  \
# ...

# %%
eng[eng.nationality == "England"] #filters english players
# Out:
#        sofifa_id                                         player_url  \
# 12        202126  https://sofifa.com/player/202126/harry-kane/20...
# 26        202652  https://sofifa.com/player/202652/raheem-sterli...
# 108       233049  https://sofifa.com/player/233049/jadon-sancho/...
# 113       211117  https://sofifa.com/player/211117/dele-alli/20/...
# 148       188377  https://sofifa.com/player/188377/kyle-walker/2...
# ...          ...                                                ...
# 18253     250739  https://sofifa.com/player/250739/nathan-morley...
# 18255     252548  https://sofifa.com/player/252548/connor-heath/...
# 18256     241493  https://sofifa.com/player/241493/samuel-cartwr...
# 18265     241828  https://sofifa.com/player/241828/luke-offord/2...
# 18270     252568  https://sofifa.com/player/252568/mohammed-saga...
#
#           short_name          long_name  age         dob  height_cm  \
# 12           H. Kane         Harry Kane   25   7/28/1993        188
# ...

# %%
#In this project i have used pandas library and players20 dataset from kaggle
#The aim of this project is to find the best players from the dataset that belong to England nationality
#Each cell below gives a result of players that are best in thier position
#I have used dataframe filtering for this demo 
#I have used 3 attributes for filtering that is nationality,overallrating and position

# %%
#i have divided the dataframe into different positions according to the dataset and for each position of the dataset i have found the best player
# in the end all the best players from different position displays best squad of english players
# team positions selected -
#ST
#RW
#LW
#CAM
#RCM
#CDM
#LCB
#RCB
#LB
#RB
#GK

# %%
eng[(eng.nationality == "England") & (eng.overall>86) & (eng.team_position == 'ST')]  #best english striker
# Out:
#     sofifa_id                                         player_url short_name  \
# 12     202126  https://sofifa.com/player/202126/harry-kane/20...    H. Kane
#
#      long_name  age        dob  height_cm  weight_kg nationality  \
# 12  Harry Kane   25  7/28/1993        188         89     England
#
#                  club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 12  Tottenham Hotspur  ...  65+3  66+3  66+3  66+3  65+3  62+3  60+3  60+3
#
#      rcb    rb
# 12  60+3  62+3
#
# [1 rows x 104 columns]

# %%
eng[(eng.nationality == "England") & (eng.overall>85) & (eng.team_position == 'LW')] #best english left winger
# Out:
#     sofifa_id                                         player_url   short_name  \
# 26     202652  https://sofifa.com/player/202652/raheem-sterli...  R. Sterling
#
#           long_name  age        dob  height_cm  weight_kg nationality  \
# 26  Raheem Sterling   24  12/8/1994        170         69     England
#
#                club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 26  Manchester City  ...  68+3  62+3  62+3  62+3  68+3  64+3  51+3  51+3
#
#      rcb    rb
# 26  51+3  64+3
#
# [1 rows x 104 columns]

# %%
eng[(eng.nationality == "England") & (eng.overall>80) & (eng.team_position == 'RM')] #best english right winger
# Out:
#      sofifa_id                                         player_url short_name  \
# 108     233049  https://sofifa.com/player/233049/jadon-sancho/...  J. Sancho
#
#         long_name  age        dob  height_cm  weight_kg nationality  \
# 108  Jadon Sancho   19  3/25/2000        180         76     England
#
#                   club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 108  Borussia Dortmund  ...  64+2  58+2  58+2  58+2  64+2  59+2  47+2  47+2
#
#       rcb    rb
# 108  47+2  59+2
#
# [1 rows x 104 columns]

# %%
eng[(eng.nationality == "England") & (eng.overall>82) & (eng.team_position == 'CAM')]  #best england attacking midfielder
# Out:
#      sofifa_id                                         player_url short_name  \
# 113     211117  https://sofifa.com/player/211117/dele-alli/20/...    D. Alli
#
#          long_name  age        dob  height_cm  weight_kg nationality  \
# 113  Bamidele Alli   23  4/11/1996        188         80     England
#
#                   club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 113  Tottenham Hotspur  ...  76+3  78+3  78+3  78+3  76+3  75+3  74+3  74+3
#
#       rcb    rb
# 113  74+3  75+3
#
# [1 rows x 104 columns]

# %%
eng[(eng.nationality == "England") & (eng.overall>75) & (eng.team_position == 'CDM')] #best english defensive midfielder
# Out:
#      sofifa_id                                         player_url short_name  \
# 755     234378  https://sofifa.com/player/234378/declan-rice/2...    D. Rice
#
#        long_name  age        dob  height_cm  weight_kg nationality  \
# 755  Declan Rice   20  1/14/1999        185         80     England
#
#                 club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 755  West Ham United  ...  70+2  76+2  76+2  76+2  70+2  71+2  76+2  76+2
#
#       rcb    rb
# 755  76+2  71+2
#
# [1 rows x 104 columns]

# %%
eng[(eng.nationality == "England") & (eng.overall>75) & (eng.team_position == 'RCM') & (eng.player_positions == 'CM')] #best english Right midfielder/Central midfielder
# Out:
#       sofifa_id                                         player_url  \
# 1192     189280  https://sofifa.com/player/189280/ashley-westwo...
#
#        short_name        long_name  age       dob  height_cm  weight_kg  \
# 1192  A. Westwood  Ashley Westwood   29  4/1/1990        174         73
#
#      nationality     club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# 1192     England  Burnley  ...  75+2  77+2  77+2  77+2  75+2  74+2  73+2
#
#         cb   rcb    rb
# 1192  73+2  73+2  74+2
#
# [1 rows x 104 columns]

# %%
eng[(eng.nationality == "England") & (eng.overall>80) & (eng.team_position == 'LCB')] #best left center back
# Out:
#      sofifa_id                                         player_url  short_name  \
# 280     203263  https://sofifa.com/player/203263/harry-maguire...  H. Maguire
#
#          long_name  age       dob  height_cm  weight_kg nationality  \
# 280  Harry Maguire   26  3/5/1993        194        100     England
#
#                   club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 280  Manchester United  ...  70+2  78+2  78+2  78+2  70+2  72+2  81+2  81+2
#
#       rcb    rb
# 280  81+2  72+2
#
# [1 rows x 104 columns]

# %%
eng[(eng.nationality == "England") & (eng.overall>80) & (eng.team_position == 'RCB')] #best right center back
# Out:
#      sofifa_id                                         player_url short_name  \
# 172     203574  https://sofifa.com/player/203574/john-stones/2...  J. Stones
#
#        long_name  age        dob  height_cm  weight_kg nationality  \
# 172  John Stones   25  5/28/1994        188         70     England
#
#                 club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 172  Manchester City  ...  77+2  80+2  80+2  80+2  77+2  78+2  81+2  81+2
#
#       rcb    rb
# 172  81+2  78+2
#
# [1 rows x 104 columns]

# %%
eng[(eng.nationality == "England") & (eng.overall>80) & (eng.team_position == 'LB')] #best left back
# Out:
#      sofifa_id                                         player_url short_name  \
# 347     205988  https://sofifa.com/player/205988/luke-shaw/20/...    L. Shaw
#
#      long_name  age        dob  height_cm  weight_kg nationality  \
# 347  Luke Shaw   23  7/12/1995        181         75     England
#
#                   club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 347  Manchester United  ...  80+2  78+2  78+2  78+2  80+2  80+2  79+2  79+2
#
#       rcb    rb
# 347  79+2  80+2
#
# [1 rows x 104 columns]

# %%
eng[(eng.nationality == "England") & (eng.overall>83) & (eng.team_position == 'RB')] #best right back
# Out:
#      sofifa_id                                         player_url short_name  \
# 148     188377  https://sofifa.com/player/188377/kyle-walker/2...  K. Walker
#
#        long_name  age        dob  height_cm  weight_kg nationality  \
# 148  Kyle Walker   29  5/28/1990        183         70     England
#
#                 club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 148  Manchester City  ...  82+3  79+3  79+3  79+3  82+3  82+3  80+3  80+3
#
#       rcb    rb
# 148  80+3  82+3
#
# [1 rows x 104 columns]

# %%
eng[(eng.nationality == "England") & (eng.overall>80) & (eng.team_position == 'GK')] #best english goalkeeper
# Out:
#      sofifa_id                                         player_url  \
# 181     204935  https://sofifa.com/player/204935/jordan-pickfo...
#
#       short_name        long_name  age       dob  height_cm  weight_kg  \
# 181  J. Pickford  Jordan Pickford   25  3/7/1994        185         77
#
#     nationality     club  ...  lwb  ldm  cdm  rdm  rwb   lb  lcb   cb  rcb  \
# 181     England  Everton  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#       rb
# 181  NaN
#
# [1 rows x 104 columns]

# %%
#your best english squad is- 
#gk - Pickford
#lb - shaw
#rb - walker
#lcb - maguire
#rcb = stones
#rcm/cm - henderson
#cdm - rice
#cam - alli
#rw - sterling
#lw - sancho
#st - kane
